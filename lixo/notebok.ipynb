# %%
from pathlib import Path
import pandas as pd
def processar(path_raw):
        df = pd.read_csv(path_raw)
        # df['datetime'] = pd.to_datetime(df['datetime'])
        # df['temp_media'] = (df['tempmax'] + df['tempmin']) / 2
        # df['amplitude_termica'] = df['tempmax'] - df['tempmin']
        # df['dia_semana'] = df['datetime'].dt.day_name()
        
        # path_processed = Path("/opt/airflow/data/processed/Processado.csv")
        # path_processed.parent.mkdir(parents=True, exist_ok=True)  # isso cria a pasta processed
        # df_limpo.to_csv(path_processed, index=False)

        
        # colunas_importantes = ['name', 'datetime', 'tempmax', 'tempmin', 'temp', 
        #                   'feelslike', 'precip', 'humidity', 'windspeed', 
        #                   'temp_media', 'amplitude_termica', 'dia_semana']
        
        # df_limpo = df[colunas_importantes]
        # df_limpo.to_csv(path_processed, index =False)
        print(df.head())
        
       
processar("/home/guiandreis/airflow-tempo-projeto/data/testedags/Caxias do Sul_20260206.csv")
# Out:
#             name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  Caxias do Sul  2026-02-05     31.0     15.7  22.7          32.9
# 1  Caxias do Sul  2026-02-06     33.6     16.5  23.7          32.0
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          15.7       23.0  16.6      72.3  ...         26.9        9
# 1          16.5       23.6  15.6      67.1  ...         28.3       10
#
#    severerisk              sunrise               sunset  moonphase  \
# 0          10  2026-02-05T05:58:15  2026-02-05T19:18:55       0.62
# 1          10  2026-02-06T05:59:04  2026-02-06T19:18:14       0.65
#
#          conditions                           description               icon  \
# 0             Clear  Clear conditions throughout the day.          clear-day
# 1  Partially cloudy     Becoming cloudy in the afternoon.  partly-cloudy-day
#
#             stations
# 0  SBCX,remote,E7074
# 1  SBCX,remote,E7074
#
# [2 rows x 33 columns]

# %%
from urllib.parse import quote
import pendulum 


def extrair_dados(cidade, ds=None, ds_nodash=None):
    file_path = f"/opt/airflow/data/testedags/{cidade}_{ds_nodash}.csv"
# Certifique que a pasta existe:
    path_raw = Path("/opt/airflow/data/testedags").mkdir(parents=True, exist_ok=True)

    
    start_date = pendulum.parse(ds).subtract(days=1).format('YYYY-MM-DD')
    end_date = pendulum.parse(ds).format('YYYY-MM-DD')

    load_dotenv()  # Busca .env na raiz automaticamente
    VISUAL_CROSSING_KEY = os.getenv('VISUAL_CROSSING_KEY')
    
    city_encoded = quote(cidade)
    url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{city_encoded}/{start_date}/{end_date}?unitGroup=metric&include=days&key={VISUAL_CROSSING_KEY}&contentType=csv'


    df = pd.read_csv(url)
    
    print('file_path')

extrair_dados('Caxias do Sul')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /usr/lib/python3.10/pathlib.py:1175, in Path.mkdir(self, mode, parents, exist_ok)
#    1174 try:
# -> 1175     self._accessor.mkdir(self, mode)
#    1176 except FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/opt/airflow/data/testedags'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File /usr/lib/python3.10/pathlib.py:1175, in Path.mkdir(self, mode, parents, exist_ok)
#    1174 try:
# -> 1175     self._accessor.mkdir(self, mode)
#    1176 except FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/opt/airflow/data'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[11], line 25
#      21     df = pd.read_csv(url)
#      23     print('file_path')
# ---> 25 extrair_dados('Caxias do Sul')
#
# Cell In[11], line 8, in extrair_dados(cidade, ds, ds_nodash)
#       6     file_path = f"/opt/airflow/data/testedags/{cidade}_{ds_nodash}.csv"
#       7 # Certifique que a pasta existe:
# ----> 8     path_raw = Path("/opt/airflow/data/testedags").mkdir(parents=True, exist_ok=True)
#      11     start_date = pendulum.parse(ds).subtract(days=1).format('YYYY-MM-DD')
#      12     end_date = pendulum.parse(ds).format('YYYY-MM-DD')
#
# File /usr/lib/python3.10/pathlib.py:1179, in Path.mkdir(self, mode, parents, exist_ok)
#    1177     if not parents or self.parent == self:
#    1178         raise
# -> 1179     self.parent.mkdir(parents=True, exist_ok=True)
#    1180     self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1181 except OSError:
#    1182     # Cannot rely on checking for EEXIST, since the operating system
#    1183     # could give priority to other errors like EACCES or EROFS
#
# File /usr/lib/python3.10/pathlib.py:1179, in Path.mkdir(self, mode, parents, exist_ok)
#    1177     if not parents or self.parent == self:
#    1178         raise
# -> 1179     self.parent.mkdir(parents=True, exist_ok=True)
#    1180     self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1181 except OSError:
#    1182     # Cannot rely on checking for EEXIST, since the operating system
#    1183     # could give priority to other errors like EACCES or EROFS
#
# File /usr/lib/python3.10/pathlib.py:1175, in Path.mkdir(self, mode, parents, exist_ok)
#    1171 """
#    1172 Create a new directory at this given path.
#    1173 """
#    1174 try:
# -> 1175     self._accessor.mkdir(self, mode)
#    1176 except FileNotFoundError:
#    1177     if not parents or self.parent == self:
#
# PermissionError: [Errno 13] Permission denied: '/opt/airflow'
